# %%
import sys
import os

# Add the project root to sys.path
sys.path.append(os.path.abspath(os.path.join("..", "..")))

from busted_ml.scraper.scraper import scrape_headlines

# Calling the scraper function
headlines = scrape_headlines()

# Showing results
for i, h in enumerate(headlines, 1):
    print(f"{i}. {h}")
# Out:
# 1. 'We knew the family': Utah town in disbelief after local resident accused of killing Charlie Kirk
# 2. Mandelson should never have been ambassador, says Epstein victim's family
# 3. Trump's coming to Britain. Let the royal schmooze-fest begin
# 4. Dozens of officers injured as up to 150,000 join Tommy Robinson rally
# 5. Queen give the BBC Proms a Rhapsodic send-off
# 6. Mandelson should never have been ambassador, says Epstein victim's family
# 7. Nepal's major parties say dissolved parliament must be reinstated
# 8. The Indian city that sparkles like Paris at night
# 9. Kashmir's young are preserving history -  one post at a time
# 10. Trump's coming to Britain. Let the royal schmooze-fest begin
